# %%
import os
import json
data_root = "../data/refGeo/sft"
data_filenames = ["avvg_detection_hbb.json", "dior_detection_hbb.json", "dota_detection_hbb.json", "fair1m_detection_hbb.json", "swift_hbb_dior_rsvg.json", "swift_hbb_refGeo.json"]
avvg = json.load(open(os.path.join(data_root, "avvg_detection_hbb.json")))
dior = json.load(open(os.path.join(data_root, "dior_detection_hbb.json")))
dota = json.load(open(os.path.join(data_root, "dota_detection_hbb.json")))
fair1m = json.load(open(os.path.join(data_root, "fair1m_detection_hbb.json")))
swift_dior = json.load(open(os.path.join(data_root, "swift_hbb_dior_rsvg.json")))
swift_refGeo = json.load(open(os.path.join(data_root, "swift_hbb_refGeo.json")))

# %%
print("avvg:", len(avvg))
print(avvg[0]); print(avvg[1])
print("dior:", len(dior))
print(dior[0]); print(dior[1])
print("dota:", len(dota))
print(dota[0]); print(dota[1])
print("fair1m:", len(fair1m))
print(fair1m[0]); print(fair1m[1])
print("swift_dior:", len(swift_dior))
print(swift_dior[0]); print(swift_dior[1])
print("swift_refGeo:", len(swift_refGeo))
print(swift_refGeo[0]); print(swift_refGeo[1])
# Out:
# avvg: 61600
# {'id': '0', 'image': 'avvg/0be3ceba-DJI_0001.JPG', 'conversations': [{'from': 'human', 'value': '\n[refer] give me the bounding boxes of all <ref>brown car</ref>'}, {'from': 'gpt', 'value': '[[104,-24,189,145]]'}]}
# {'id': '1', 'image': 'avvg/0be3ceba-DJI_0001.JPG', 'conversations': [{'from': 'human', 'value': '\n[refer] give me the bounding boxes of all <ref>suv car</ref>'}, {'from': 'gpt', 'value': '[[104,-24,189,145]]'}]}
# dior: 184050
# {'id': '0', 'image': 'dior/00005.jpg', 'conversations': [{'from': 'human', 'value': '\n[refer] give me the bounding box of <ref>storagetank</ref> is'}, {'from': 'gpt', 'value': '[[47,40,62,54]]'}]}
# {'id': '1', 'image': 'dior/00005.jpg', 'conversations': [{'from': 'human', 'value': '\n[refer] give me the bounding box of <ref>vehicle</ref> is'}, {'from': 'gpt', 'value': '[[23,30,25,33],[0,84,4,86]]'}]}
# dota: 184835
# ...
